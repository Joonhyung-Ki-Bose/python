# %% [markdown]
# # Reading Files Python
# r Read mode for reading files /
# w Write mode for writing files

# %%
example1 = "C:/Users/jk1050404/OneDrive - Bose Corporation/_MOT/파이썬프로그래밍/실습자료/example1.txt"
file1 = open(example1, "r") #"r"는 example1 객체를 읽을 수 있는 상태로 만들자.

# %%
file1.name
# Out:
# 'C:/Users/jk1050404/OneDrive - Bose Corporation/_MOT/파이썬프로그래밍/실습자료/example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
type(FileContent)
# Out:
# str

# %%
file1.close() # 마지막으로 닫는다.

# %% [markdown]
# ---

# %%
with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
file1.closed
# Out:
# True

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
# (empty)
# This is line 4

# %%
with open(example1, "r") as file1:
    print(file1.read(4)) # 4글자만 읽어 온다.
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
with open(example1, "r") as file1:
    print("first line: " + file1.readline())
    print("second line: " + file1.readline())
    print("third line: " + file1.readline())
# Out:
# first line: This is line 1
#
# second line: This is line 2
#
# third line: This is line 3

# %%
with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1;
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3
#
# Iteration 3 :  (empty)
#
# Iteration 4 :  This is line 4

# %%
with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %%
FileasList[0]
# Out:
# 'This is line 1\n'
